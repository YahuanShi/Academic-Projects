# %% [markdown]
# # Exercise Sheet - Regularization 2
#
# In this exercise we will take a look at simple but effective methods used to combat overfitting when learning neural networks. We will use a very small subset of the FashionMNIST dataset to artificially induce overfitting, train and evaluate our model. Finally we will look at how to incorporate early stopping and how adding noise to our data makes our model more robust.

# %%
from typing import Callable
from functools import partial

import torch
from torch import nn
from torch.optim import Optimizer, SGD

from torchvision.transforms import v2

# from solution import *
from utils import *

DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
DEVICE
# Out:
# 'cpu'

# %% [markdown]
# # Training configuration
#
# Throughout this notebook we will use the following training configuration:

# %%
TRAIN_SET_SIZE = 200
VAL_SET_SIZE = 1000
EPOCHS = 500
HIDDEN_DIMS = [64, 32]
LR = 0.05
BATCH_SIZE = 32

# %% [markdown]
# # Dataset (FashionMNIST)
#
# As mentioned before, we will use the FashionMNIST dataset. This dataset behaves exactly the same as the standard MNIST dataset (grayscale images with height and width of 28 pixels, 10 classes (0-9), train set with 60k samples and test set with 10k samples) with the only difference being the depicted images. While MNIST shows handwritten digits, FashionMNIST shows 10 different types of clothing. Example images are shown after execution of the following cell.

# %%
train_set, val_set, test_set = get_fashion_mnist_subset(TRAIN_SET_SIZE, VAL_SET_SIZE, transforms=v2.ToTensor())

train_loader = DataLoader(train_set, batch_size=BATCH_SIZE, shuffle=True)
val_loader = DataLoader(val_set, batch_size=BATCH_SIZE)
test_loader = DataLoader(test_set, batch_size=BATCH_SIZE)

visualize_first_4(train_loader)
# Out:
# Shape of images is torch.Size([32, 1, 28, 28])

# %% [markdown]
# # Create model
#
# First, we need a function to create a model that is able to classify FashionMNIST data. The model takes in inputs of the shape (batch_size x 1 x 28 x 28) and outputs a 10-dimensional vector. It should first flatten the input images, then apply a given number of linear layers to it, and finally map to a 10-dimensional vector which will be used to predict which type of clothing it is.

# %% [markdown]
# ## Task 1a) (20 P)
#
# Complete the missing code in the following function. The function takes a list of hidden dimensions which correspond to the dimensionality of the linear layers. The input dimension of 28 x 28 and the output dimension of 10 should be hardcoded into the model. There should be as many layers as hidden dimensions, plus a final output layer. As an activation function we will use the ReLU activation.

# %%
def create_model(hidden_dims: list[int]):  # TODO: explain in docstring that input is written without brackets
    """Create a model that works for classifying the FahsionMNIST dataset."""
    # --------------------------------------------------
    # TODO: Replace by your code
    # --------------------------------------------------
    layers = []
    input_dim = 28 * 28
    for dim in hidden_dims:
        layers.append(nn.Linear(input_dim, dim))
        layers.append(nn.ReLU())
        input_dim = dim    
    layers.append(nn.Linear(input_dim, 10))
    model = nn.Sequential(*layers)
    # --------------------------------------------------

    model.to(DEVICE)
    return model

# %% [markdown]
# # Train, evaluate and save models

# %% [markdown]
# ## Task 2a) (20 P)
# Write a function that trains a model for one epoch / one iteration through the train dataset. Make sure to zero the gradients before each step and to apply the optimizers functions to train the model. This is a repetition from last exercise, so check there in case you are unsure.

# %%
def train_one_epoch(model, dataloader, optimizer):
    # --------------------------------------------------
    # TODO: Replace by your code
    # --------------------------------------------------
    model.train()
    total_loss = 0
    for inputs, labels in dataloader:
        inputs, labels = inputs.to(DEVICE), labels.to(DEVICE)
        optimizer.zero_grad()
        outputs = model(inputs.view(inputs.size(0), -1))          
        loss = nn.CrossEntropyLoss()(outputs, labels)
        loss.backward()
        optimizer.step()
        total_loss += loss.item()
        avg_loss = total_loss / len(dataloader)
    # --------------------------------------------------
    return avg_loss

# %% [markdown]
# ## Task 2b) (20 P)
#
# Write a function that iterates through a dataloader, and outputs the average loss and accuracy. Make sure that no gradient computation is triggered, e.g. use [torch.no_grad()](https://pytorch.org/docs/stable/generated/torch.no_grad.html). Furthermore, make sure that your model in evaluation mode and to switch back afterwards. This will be important for the last task where we are adding Dropout layers to our neural network. For more information see [this](https://stackoverflow.com/questions/60018578/what-does-model-eval-do-in-pytorch) StackOverflow question.

# %%
def validate(model: nn.Module, dataloader: DataLoader) -> tuple[float, float]:
    # --------------------------------------------------
    # TODO: Replace by your code
    # --------------------------------------------------
    model.eval()
    total_loss = 0
    correct = 0
    with torch.no_grad():
        for inputs, labels in dataloader:
            inputs, labels = inputs.to(DEVICE), labels.to(DEVICE)
            outputs = model(inputs.view(inputs.size(0), -1))
            loss = nn.CrossEntropyLoss()(outputs, labels)
            total_loss += loss.item()
            preds = outputs.argmax(dim=1)
            correct += (preds == labels).sum().item()
    avg_loss = total_loss / len(dataloader)
    avg_accuracy = correct / len(dataloader.dataset)
    # --------------------------------------------------
    return avg_loss, avg_accuracy

# %% [markdown]
# Here we define our complete training function. It simply iterates for `n_epochs` epochs through the training dataset, evaluates after each epoch on the validation dataset, and finally returns an array with the train and validation losses for each epoch. An important feature of this training function is that it can take a function as an argument (that's the `callback` argument) which gets the model, the current epoch, the array of train losses up until this point, the array of validation losses until this point and the last validation accuracy. The follwing tasks will partly consist of writing functions that we will pass into the training function.

# %%
def train(
        model: nn.Module,
        train_loader: DataLoader,
        val_loader: DataLoader,
        optimizer: Optimizer,
        n_epochs: int,
        callback: Callable[[nn.Module, int, list[float], list[float], float], None]
    ) -> tuple[list[float], list[float]]:
    train_losses = []
    val_losses = []
    for epoch in range(n_epochs):
        train_loss = train_one_epoch(model, train_loader, optimizer)
        val_loss, val_acc = validate(model, val_loader)

        train_losses.append(train_loss)
        val_losses.append(val_loss)

        callback(model, epoch, train_losses, val_losses, val_acc)

    return train_losses, val_losses

# %% [markdown]
# ## Task 2c) (10 P)
#
# In this task you should simply write a function that we can pass into the training function above that prints the current stats every `n` epochs. This function shouldn't return anything.

# %%
def print_loss_every_n_epochs(
        model: nn.Module,
        epoch: int,
        train_losses: list[float],
        val_losses: list[float],
        val_acc,
        n: int) -> None:
    # --------------------------------------------------
    # TODO: Replace by your code
    # --------------------------------------------------
    if epoch % n == 0:
        print(f"[EPOCH {epoch}] Train Loss: {train_losses[-1]:.4f}, "
              f"Validation Loss: {val_losses[-1]:.4f}, Validation Accuracy: {val_acc:.4f}")
    # --------------------------------------------------

# %% [markdown]
# Next we will train a model. We will use the above defined hyperparameters, and a simple SGD optimizer. Furthermore we will print the training stats every epoch.

# %%
model = create_model(HIDDEN_DIMS)
optimizer = SGD(model.parameters(), lr=LR)

train_losses , val_losses = train(model,
                                   train_loader,
                                   val_loader,
                                   optimizer,
                                   n_epochs=10,
                                   callback=partial(print_loss_every_n_epochs, n=1))

plot_train_and_val_loss(train_losses, val_losses, title=f"min. validation loss: {min(val_losses):.4f}")
# Out:
# [EPOCH 0] Train Loss: 2.3081, Validation Loss: 2.2876, Validation Accuracy: 0.1190
# [EPOCH 1] Train Loss: 2.2748, Validation Loss: 2.2646, Validation Accuracy: 0.1260
# [EPOCH 2] Train Loss: 2.2277, Validation Loss: 2.2390, Validation Accuracy: 0.1500
# [EPOCH 3] Train Loss: 2.1875, Validation Loss: 2.2076, Validation Accuracy: 0.1410
# [EPOCH 4] Train Loss: 2.1447, Validation Loss: 2.1639, Validation Accuracy: 0.2590
# [EPOCH 5] Train Loss: 2.0896, Validation Loss: 2.1004, Validation Accuracy: 0.2890
# [EPOCH 6] Train Loss: 2.0043, Validation Loss: 2.0115, Validation Accuracy: 0.2430
# [EPOCH 7] Train Loss: 1.9136, Validation Loss: 1.9226, Validation Accuracy: 0.2700
# [EPOCH 8] Train Loss: 1.8175, Validation Loss: 1.8654, Validation Accuracy: 0.2760
# [EPOCH 9] Train Loss: 1.7677, Validation Loss: 1.7188, Validation Accuracy: 0.3380

# %% [markdown]
# # Early stopping
#
# Early stopping is the most simple thing to prevent your final model to overfit: you simply track train and test errors and use a model checkpoint before your model started to overfit.

# %% [markdown]
# ## Task 3a) (10 P)
#
# Implementing early stopping is pretty straight forward. Simply save your model each time you've reached a new best validation loss, and otherwise don't. To reduce clutter in your filesystem you can simply override the saved model each time. Saving and loading PyTorch models is described in [this guide](https://pytorch.org/tutorials/beginner/saving_loading_models.html). The function to load models is given.

# %%
def save_model_if_improved(model, epoch, train_losses, val_losses, val_acc, filename):
    # --------------------------------------------------
    # TODO: Replace by your code
    # --------------------------------------------------
    min_loss = min(val_losses)
    if val_losses[-1] <= min_loss:
        print(f"Found new best model at epoch {epoch} with a validation loss of {val_losses[-1]:.4f}, saving model to {filename}")
        torch.save(model.state_dict(), filename)
    # --------------------------------------------------

def load_model(model, model_file_path: str) -> nn.Module:
    model.load_state_dict(torch.load(model_file_path, weights_only=True))
    return model

# %% [markdown]
# This time we will train our model for more epochs, to show how it overfits. Your implemented function should stop saving the model once the model starts to overfit.

# %%
model = create_model(HIDDEN_DIMS)
optimizer = SGD(model.parameters(), lr=LR)
train_losses, val_losses = train(model,
                                train_loader,
                                val_loader,
                                optimizer,
                                n_epochs=EPOCHS,
                                callback=partial(save_model_if_improved, filename="early_stopping.pth"))

plot_train_and_val_loss(train_losses, val_losses, title=f"min. validation loss: {min(val_losses):.4f}")
# Out:
# Found new best model at epoch 0 with a validation loss of 2.2740, saving model to early_stopping.pth
# Found new best model at epoch 1 with a validation loss of 2.2444, saving model to early_stopping.pth
# Found new best model at epoch 2 with a validation loss of 2.2102, saving model to early_stopping.pth
# Found new best model at epoch 3 with a validation loss of 2.1661, saving model to early_stopping.pth
# Found new best model at epoch 4 with a validation loss of 2.1118, saving model to early_stopping.pth
# Found new best model at epoch 5 with a validation loss of 2.0512, saving model to early_stopping.pth
# Found new best model at epoch 6 with a validation loss of 1.9562, saving model to early_stopping.pth
# Found new best model at epoch 7 with a validation loss of 1.8783, saving model to early_stopping.pth
# Found new best model at epoch 8 with a validation loss of 1.8022, saving model to early_stopping.pth
# Found new best model at epoch 9 with a validation loss of 1.6477, saving model to early_stopping.pth
# Found new best model at epoch 10 with a validation loss of 1.5757, saving model to early_stopping.pth
# Found new best model at epoch 11 with a validation loss of 1.4648, saving model to early_stopping.pth
# Found new best model at epoch 12 with a validation loss of 1.3858, saving model to early_stopping.pth
# Found new best model at epoch 13 with a validation loss of 1.3546, saving model to early_stopping.pth
# Found new best model at epoch 14 with a validation loss of 1.2578, saving model to early_stopping.pth
# Found new best model at epoch 15 with a validation loss of 1.2165, saving model to early_stopping.pth
# Found new best model at epoch 16 with a validation loss of 1.1656, saving model to early_stopping.pth
# Found new best model at epoch 19 with a validation loss of 1.1230, saving model to early_stopping.pth
# Found new best model at epoch 22 with a validation loss of 0.9445, saving model to early_stopping.pth
# Found new best model at epoch 25 with a validation loss of 0.9323, saving model to early_stopping.pth
# Found new best model at epoch 28 with a validation loss of 0.8932, saving model to early_stopping.pth
# Found new best model at epoch 31 with a validation loss of 0.8437, saving model to early_stopping.pth
# Found new best model at epoch 33 with a validation loss of 0.8121, saving model to early_stopping.pth
# Found new best model at epoch 34 with a validation loss of 0.7848, saving model to early_stopping.pth
# Found new best model at epoch 38 with a validation loss of 0.7752, saving model to early_stopping.pth
# Found new best model at epoch 39 with a validation loss of 0.7400, saving model to early_stopping.pth
# Found new best model at epoch 58 with a validation loss of 0.7252, saving model to early_stopping.pth
# Found new best model at epoch 74 with a validation loss of 0.7171, saving model to early_stopping.pth

# %% [markdown]
# We now evaluate our model on the test set, to get a better estimate of the generalization error. As you can see we've named the model

# %%
pretrained_model = create_model(HIDDEN_DIMS)
load_model(pretrained_model, model_file_path="early_stopping.pth")
test_loss, test_accuracy = validate(pretrained_model, test_loader)

print(f"Early stopping model achieved test loss of {test_loss:.4f} and accuarcy {test_accuracy:.4f}")
# Out:
# Early stopping model achieved test loss of 0.8221 and accuarcy 0.7207

# %% [markdown]
# # Dropout
#
# Dropout is a technique where neurons are randoml set to zero, which introduces noise into the network, and helps to generalize better. Details are described in [this blogpost](https://towardsdatascience.com/dropout-in-neural-networks-47a162d621d9).

# %% [markdown]
# ## Task 4a) (20 P)
#
# Implement a function similar to the one above where we build a standard feed forward network. But now, after each activation layer, add a [nn.Dropout()](https://pytorch.org/docs/stable/generated/torch.nn.Dropout.html) layer with the dropout probability specified in the parameter `p`.

# %%
def create_model_with_dropout(hidden_dims: list[int], p: float):
    # --------------------------------------------------
    # TODO: Replace by your code
    # --------------------------------------------------
    layers = []
    input_dim = 28 * 28
    for dim in hidden_dims:
        layers.append(nn.Linear(input_dim, dim))
        layers.append(nn.ReLU())
        layers.append(nn.Dropout(p))
        input_dim = dim    
    layers.append(nn.Linear(input_dim, 10))
    model = nn.Sequential(*layers)
    # --------------------------------------------------

    model.to(DEVICE)
    return model

# %% [markdown]
# Next we will train a neural network with the exact same parameters as above, only that we now have added dropout layers.

# %%
DROPOUT = 0.8

model = create_model_with_dropout(HIDDEN_DIMS, p=DROPOUT)
optimizer = SGD(model.parameters(), lr=LR)

train_losses, val_losses = train(model,
                                train_loader,
                                val_loader,
                                optimizer,
                                n_epochs=EPOCHS,
                                callback=partial(save_model_if_improved, filename="dropout.pth"))

plot_train_and_val_loss(train_losses, val_losses, title=f"min. validation loss: {min(val_losses):.4f}")
# Out:
# Found new best model at epoch 0 with a validation loss of 2.2969, saving model to dropout.pth
# Found new best model at epoch 1 with a validation loss of 2.2888, saving model to dropout.pth
# Found new best model at epoch 2 with a validation loss of 2.2873, saving model to dropout.pth
# Found new best model at epoch 4 with a validation loss of 2.2844, saving model to dropout.pth
# Found new best model at epoch 5 with a validation loss of 2.2839, saving model to dropout.pth
# Found new best model at epoch 6 with a validation loss of 2.2764, saving model to dropout.pth
# Found new best model at epoch 7 with a validation loss of 2.2760, saving model to dropout.pth
# Found new best model at epoch 8 with a validation loss of 2.2675, saving model to dropout.pth
# Found new best model at epoch 9 with a validation loss of 2.2579, saving model to dropout.pth
# Found new best model at epoch 10 with a validation loss of 2.2573, saving model to dropout.pth
# Found new best model at epoch 11 with a validation loss of 2.2500, saving model to dropout.pth
# Found new best model at epoch 12 with a validation loss of 2.2401, saving model to dropout.pth
# Found new best model at epoch 15 with a validation loss of 2.2331, saving model to dropout.pth
# Found new best model at epoch 16 with a validation loss of 2.2240, saving model to dropout.pth
# Found new best model at epoch 17 with a validation loss of 2.1952, saving model to dropout.pth
# Found new best model at epoch 19 with a validation loss of 2.1740, saving model to dropout.pth
# Found new best model at epoch 20 with a validation loss of 2.1730, saving model to dropout.pth
# Found new best model at epoch 23 with a validation loss of 2.1687, saving model to dropout.pth
# Found new best model at epoch 24 with a validation loss of 2.1633, saving model to dropout.pth
# Found new best model at epoch 25 with a validation loss of 2.1308, saving model to dropout.pth
# Found new best model at epoch 26 with a validation loss of 2.1220, saving model to dropout.pth
# Found new best model at epoch 27 with a validation loss of 2.1128, saving model to dropout.pth
# Found new best model at epoch 29 with a validation loss of 2.0782, saving model to dropout.pth
# Found new best model at epoch 30 with a validation loss of 2.0726, saving model to dropout.pth
# Found new best model at epoch 31 with a validation loss of 2.0586, saving model to dropout.pth
# Found new best model at epoch 32 with a validation loss of 2.0283, saving model to dropout.pth
# Found new best model at epoch 34 with a validation loss of 2.0280, saving model to dropout.pth
# Found new best model at epoch 35 with a validation loss of 2.0243, saving model to dropout.pth
# Found new best model at epoch 36 with a validation loss of 1.9929, saving model to dropout.pth
# Found new best model at epoch 37 with a validation loss of 1.9702, saving model to dropout.pth
# Found new best model at epoch 38 with a validation loss of 1.9470, saving model to dropout.pth
# Found new best model at epoch 40 with a validation loss of 1.9304, saving model to dropout.pth
# Found new best model at epoch 41 with a validation loss of 1.9118, saving model to dropout.pth
# Found new best model at epoch 42 with a validation loss of 1.9106, saving model to dropout.pth
# Found new best model at epoch 45 with a validation loss of 1.8806, saving model to dropout.pth
# Found new best model at epoch 46 with a validation loss of 1.8769, saving model to dropout.pth
# Found new best model at epoch 47 with a validation loss of 1.8723, saving model to dropout.pth
# Found new best model at epoch 48 with a validation loss of 1.8125, saving model to dropout.pth
# Found new best model at epoch 49 with a validation loss of 1.7943, saving model to dropout.pth
# Found new best model at epoch 50 with a validation loss of 1.7764, saving model to dropout.pth
# Found new best model at epoch 57 with a validation loss of 1.7677, saving model to dropout.pth
# Found new best model at epoch 60 with a validation loss of 1.7359, saving model to dropout.pth
# Found new best model at epoch 61 with a validation loss of 1.7161, saving model to dropout.pth
# Found new best model at epoch 62 with a validation loss of 1.6974, saving model to dropout.pth
# Found new best model at epoch 63 with a validation loss of 1.6949, saving model to dropout.pth
# Found new best model at epoch 65 with a validation loss of 1.6828, saving model to dropout.pth
# Found new best model at epoch 66 with a validation loss of 1.6764, saving model to dropout.pth
# Found new best model at epoch 68 with a validation loss of 1.6489, saving model to dropout.pth
# Found new best model at epoch 72 with a validation loss of 1.6354, saving model to dropout.pth
# Found new best model at epoch 75 with a validation loss of 1.6118, saving model to dropout.pth
# Found new best model at epoch 79 with a validation loss of 1.5982, saving model to dropout.pth
# Found new best model at epoch 80 with a validation loss of 1.5797, saving model to dropout.pth
# Found new best model at epoch 86 with a validation loss of 1.5782, saving model to dropout.pth
# Found new best model at epoch 88 with a validation loss of 1.5365, saving model to dropout.pth
# Found new best model at epoch 91 with a validation loss of 1.5355, saving model to dropout.pth
# Found new best model at epoch 92 with a validation loss of 1.5315, saving model to dropout.pth
# Found new best model at epoch 93 with a validation loss of 1.5180, saving model to dropout.pth
# Found new best model at epoch 96 with a validation loss of 1.4917, saving model to dropout.pth
# Found new best model at epoch 108 with a validation loss of 1.4830, saving model to dropout.pth
# Found new best model at epoch 111 with a validation loss of 1.4448, saving model to dropout.pth
# Found new best model at epoch 112 with a validation loss of 1.4359, saving model to dropout.pth
# Found new best model at epoch 114 with a validation loss of 1.4130, saving model to dropout.pth
# Found new best model at epoch 115 with a validation loss of 1.3870, saving model to dropout.pth
# Found new best model at epoch 122 with a validation loss of 1.3721, saving model to dropout.pth
# Found new best model at epoch 125 with a validation loss of 1.3596, saving model to dropout.pth
# Found new best model at epoch 134 with a validation loss of 1.3527, saving model to dropout.pth
# Found new best model at epoch 136 with a validation loss of 1.3402, saving model to dropout.pth
# Found new best model at epoch 138 with a validation loss of 1.3270, saving model to dropout.pth
# Found new best model at epoch 148 with a validation loss of 1.3128, saving model to dropout.pth
# Found new best model at epoch 150 with a validation loss of 1.3002, saving model to dropout.pth
# Found new best model at epoch 152 with a validation loss of 1.2988, saving model to dropout.pth
# Found new best model at epoch 153 with a validation loss of 1.2795, saving model to dropout.pth
# Found new best model at epoch 164 with a validation loss of 1.2630, saving model to dropout.pth
# Found new best model at epoch 165 with a validation loss of 1.2506, saving model to dropout.pth
# Found new best model at epoch 173 with a validation loss of 1.2466, saving model to dropout.pth
# Found new best model at epoch 175 with a validation loss of 1.2291, saving model to dropout.pth
# Found new best model at epoch 187 with a validation loss of 1.2243, saving model to dropout.pth
# Found new best model at epoch 188 with a validation loss of 1.2168, saving model to dropout.pth
# Found new best model at epoch 191 with a validation loss of 1.1985, saving model to dropout.pth
# Found new best model at epoch 194 with a validation loss of 1.1951, saving model to dropout.pth
# Found new best model at epoch 206 with a validation loss of 1.1740, saving model to dropout.pth
# Found new best model at epoch 213 with a validation loss of 1.1636, saving model to dropout.pth
# Found new best model at epoch 251 with a validation loss of 1.1619, saving model to dropout.pth
# Found new best model at epoch 253 with a validation loss of 1.1556, saving model to dropout.pth
# Found new best model at epoch 304 with a validation loss of 1.1521, saving model to dropout.pth
# Found new best model at epoch 311 with a validation loss of 1.1414, saving model to dropout.pth
# Found new best model at epoch 314 with a validation loss of 1.1353, saving model to dropout.pth
# Found new best model at epoch 324 with a validation loss of 1.1270, saving model to dropout.pth
# Found new best model at epoch 330 with a validation loss of 1.1232, saving model to dropout.pth
# Found new best model at epoch 338 with a validation loss of 1.1116, saving model to dropout.pth
# Found new best model at epoch 349 with a validation loss of 1.0996, saving model to dropout.pth
# Found new best model at epoch 393 with a validation loss of 1.0911, saving model to dropout.pth

# %%
pretrained_model = create_model_with_dropout(HIDDEN_DIMS, DROPOUT)
load_model(pretrained_model, "dropout.pth")
test_loss, test_accuracy = validate(pretrained_model, test_loader)

print(f"Dropout model achieved test loss of {test_loss:.4f} and accuracy of {test_accuracy:.4f}")
# Out:
# Dropout model achieved test loss of 1.1600 and accuracy of 0.5944
